# %%
import numpy as np
import matplotlib.pyplot as plt

directory = "/home/toddmendenhall/Downloads/"
uniform = np.loadtxt(directory + "time_evolution_uniform.csv", delimiter=",").T
semicircle = np.loadtxt(directory + "time_evolution_semicircle.csv", delimiter=",").T

# %%
plt.plot(uniform[0], uniform[1])
plt.plot(semicircle[0], semicircle[1])
plt.show()

# %%
plt.plot(uniform[0], semicircle[1] / uniform[1])
plt.plot(uniform[0], semicircle[2] / uniform[2])
plt.show()
# Out:
# /tmp/ipykernel_47443/4281391156.py:1: RuntimeWarning: invalid value encountered in divide
#   plt.plot(uniform[0], semicircle[1] / uniform[1])
# /tmp/ipykernel_47443/4281391156.py:2: RuntimeWarning: invalid value encountered in divide
#   plt.plot(uniform[0], semicircle[2] / uniform[2])
